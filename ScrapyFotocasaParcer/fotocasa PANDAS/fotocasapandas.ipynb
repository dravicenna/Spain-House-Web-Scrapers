# %%
import pandas as pd

# %%
df1 = pd.read_csv('Fotocasa.csv', delimiter=',')#, parse_dates=[6], nrows = nRowsRead)
df1.create_date = pd.to_datetime(df1.create_date, errors='coerce', format='%d/%m/%Y %H:%M:%S', dayfirst=True)

# %%
df1.head(5)
# Out:
#        phone                                     featuresValues     planta  \
# 0  932753425                          "terraza,balcon,lavadero"  3ª planta
# 1  944943352  "armarios,calefaccion,terraza,ascensor,amuebla...  4ª planta
# 2  952140746  "aire-acondicionado,armarios,calefaccion,garaj...        NaN
# 3  928194387                                                 ""        NaN
# 4  912172763  "aire-acondicionado,armarios,calefaccion,garaj...        NaN
#
#    ABTest      ad_id  promotion_id  ad_publisher_type_id        ads_name_page  \
# 0     NaN  147462618             0                     1  fotocasaes/tv/ficha
# 1     NaN  149843274             0                     1  fotocasaes/tv/ficha
# 2     NaN  149873085             0                     1  fotocasaes/tv/ficha
# 3     NaN  149997962             0                     1  fotocasaes/tv/ficha
# 4     NaN  148366355             0                     1  fotocasaes/tv/ficha
#
# ...

# %%
df1.columns
# Out:
# Index(['phone', 'featuresValues', 'planta', 'ad_id', 'promotion_id',
#        'ad_publisher_type_id', 'ads_name_page', 'city', 'city_id', 'city_zone',
#        'company_idwas', 'county', 'county_id', 'district_id', 'mts2',
#        'mts2_max', 'mts2_min', 'neighbourhood', 'neighbourhood_id',
#        'postal_code', 'price', 'price_max', 'price_min', 'property',
#        'property_id', 'property_state', 'property_state_id', 'property_sub',
#        'property_sub_id', 'query', 'region_level2', 'region_level2_id',
#        'reload', 'rooms', 'search_terms', 'site', 'street', 'transaction_id',
#        'water_id', 'ad_publisher_id', 'ad_publisher_type', 'ad_title',
#        'bathrooms', 'city_zone_id', 'country', 'country_id', 'create_date',
#        'district', 'event_name', 'features', 'image_urls', 'full_description',
#        'url', 'images'],
#       dtype='object')

# %%
del df1['features_id']
del df1['ads_name_page']

# %%
data = df1[['phone', 'featuresValues', 'planta', 'ad_id', 'promotion_id',
       'ad_publisher_type_id', 'city', 'city_id', 'city_zone', 'county', 'county_id', 'district_id', 'mts2',
       'mts2_max', 'mts2_min', 'neighbourhood', 'neighbourhood_id',
       'postal_code', 'price', 'price_max', 'price_min', 'property',
       'property_id', 'property_state', 'property_state_id', 'property_sub',
       'property_sub_id', 'query', 'region_level2', 'region_level2_id',
       'reload', 'rooms', 'search_terms', 'site', 'street', 'transaction_id',
       'water_id', 'ad_publisher_id', 'ad_publisher_type', 'ad_title',
       'bathrooms', 'city_zone_id', 'create_date',
       'district', 'full_description']]

# %%
data.apply(func=)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-f2047d92a548> in <module>()
# ----> 1 data.apply(max())
#
# TypeError: max expected 1 arguments, got 0
